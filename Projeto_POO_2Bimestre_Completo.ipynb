# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** guilherme maciel
#
# **Turma:** 2b t.i
#
# **Tema Escolhido:** sistema que registre ocorrencias escolares

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Aluno_Guilherme:
    def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme):
        self.nome_Guilherme = nome_Guilherme
        self.matricula_Guilherme = matricula_Guilherme
        self.turma_Guilherme = turma_Guilherme

    def exibir_dados_Guilherme(self):
        print(f"Nome: {self.nome_Guilherme}")
        print(f"Matrícula: {self.matricula_Guilherme}")
        print(f"Turma: {self.turma_Guilherme}")

aluno1_Guilherme = Aluno_Guilherme("Lucas Silva", "202501", "2B")
aluno2_Guilherme = Aluno_Guilherme("Mariana Costa", "202502", "2B")

print("📘 Dados do Aluno 1:")
aluno1_Guilherme.exibir_dados_Guilherme()

print("\n📘 Dados do Aluno 2:")
aluno2_Guilherme.exibir_dados_Guilherme()
# Out:
# 📘 Dados do Aluno 1:
# Nome: Lucas Silva
# Matrícula: 202501
# Turma: 2B
#
# 📘 Dados do Aluno 2:
# Nome: Mariana Costa
# Matrícula: 202502
# Turma: 2B

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
    class Aluno_Guilherme:
        def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme):
            self.nome_Guilherme = nome_Guilherme
            self.matricula_Guilherme = matricula_Guilherme
            self.turma_Guilherme = turma_Guilherme
            self.ocorrencias_Guilherme = []

        def exibir_dados_Guilherme(self):
            print(f"Nome: {self.nome_Guilherme}")
            print(f"Matrícula: {self.matricula_Guilherme}")
            print(f"Turma: {self.turma_Guilherme}")

        def adicionar_ocorrencia_Guilherme(self, ocorrencia_Guilherme):
            self.ocorrencias_Guilherme.append(ocorrencia_Guilherme)

        def listar_ocorrencias_Guilherme(self):
            if not self.ocorrencias_Guilherme:
                print("Nenhuma ocorrência registrada.")
            else:
                print(f"Ocorrências de {self.nome_Guilherme}:")
                for o in self.ocorrencias_Guilherme:
                    print(f"- {o}")

    class AlunoMonitor_Guilherme(Aluno_Guilherme):
        def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme, disciplina_monitoria_Guilherme):
            super().__init__(nome_Guilherme, matricula_Guilherme, turma_Guilherme)
            self.disciplina_monitoria_Guilherme = disciplina_monitoria_Guilherme

        def exibir_monitoria_Guilherme(self):
            print(f"{self.nome_Guilherme} é monitor da disciplina: {self.disciplina_monitoria_Guilherme}")

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Aluno_Guilherme:
    def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme):
        self.__nome_Guilherme = nome_Guilherme
        self.matricula_Guilherme = matricula_Guilherme
        self.turma_Guilherme = turma_Guilherme
        self.faltas_Guilherme = 0

    def get_nome_Guilherme(self):
        return self.__nome_Guilherme

    def set_nome_Guilherme(self, novo_nome_Guilherme):
        self.__nome_Guilherme = novo_nome_Guilherme

    def verificar_situacao_Guilherme(self):
        if self.faltas_Guilherme >= 5:
            return f"{self.__nome_Guilherme} está em risco por excesso de faltas!"
        else:
            return f"{self.__nome_Guilherme} está com presença regular."

    def adicionar_falta_Guilherme(self, quantidade):
        self.faltas_Guilherme += quantidade

aluno3_Guilherme = Aluno_Guilherme("Carlos Lima", "202503", "2B")
aluno3_Guilherme.set_nome_Guilherme("Carlos Eduardo Lima")
print("Nome do aluno:", aluno3_Guilherme.get_nome_Guilherme())
aluno3_Guilherme.adicionar_falta_Guilherme(3)
print(aluno3_Guilherme.verificar_situacao_Guilherme())
aluno3_Guilherme.adicionar_falta_Guilherme(2)
print(aluno3_Guilherme.verificar_situacao_Guilherme())
# Out:
# Nome do aluno: Carlos Eduardo Lima
# Carlos Eduardo Lima está com presença regular.
# Carlos Eduardo Lima está em risco por excesso de faltas!

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

class Aluno_Guilherme:
    def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme):
        self.__nome_Guilherme = nome_Guilherme
        self.matricula_Guilherme = matricula_Guilherme
        self.turma_Guilherme = turma_Guilherme
        self.faltas_Guilherme = 0

    def get_nome_Guilherme(self):
        return self.__nome_Guilherme

    def set_nome_Guilherme(self, novo_nome_Guilherme):
        self.__nome_Guilherme = novo_nome_Guilherme

    def verificar_situacao_Guilherme(self):
        if self.faltas_Guilherme >= 5:
            return f"{self.__nome_Guilherme} está em risco por excesso de faltas!"
        else:
            return f"{self.__nome_Guilherme} está com presença regular."

    def adicionar_falta_Guilherme(self, quantidade):
        self.faltas_Guilherme += quantidade

    def exibir_dados_Guilherme(self):
        print(f"Aluno: {self.__nome_Guilherme}, Matrícula: {self.matricula_Guilherme}, Turma: {self.turma_Guilherme}")

class AlunoMonitor_Guilherme(Aluno_Guilherme):
    def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme, disciplina_monitoria_Guilherme):
        super().__init__(nome_Guilherme, matricula_Guilherme, turma_Guilherme)
        self.disciplina_monitoria_Guilherme = disciplina_monitoria_Guilherme

    def exibir_dados_Guilherme(self):
        print(f"Monitor: {self.get_nome_Guilherme()}, Matrícula: {self.matricula_Guilherme}, Turma: {self.turma_Guilherme}")
        print(f"Disciplina que monitora: {self.disciplina_monitoria_Guilherme}")

conexao_Guilherme = sqlite3.connect('escola_Guilherme.db')
cursor_Guilherme = conexao_Guilherme.cursor()

cursor_Guilherme.execute('''
CREATE TABLE IF NOT EXISTS alunos_Guilherme (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome TEXT,
    matricula TEXT,
    turma TEXT
)
''')
conexao_Guilherme.commit()

def inserir_aluno_Guilherme(nome, matricula, turma):
    cursor_Guilherme.execute("INSERT INTO alunos_Guilherme (nome, matricula, turma) VALUES (?, ?, ?)",
                             (nome, matricula, turma))
    conexao_Guilherme.commit()
    print(" Aluno inserido com sucesso!")

def listar_alunos_Guilherme():
    cursor_Guilherme.execute("SELECT * FROM alunos_Guilherme")
    alunos = cursor_Guilherme.fetchall()
    print(" Lista de alunos:")
    for aluno in alunos:
        print(aluno)

def deletar_aluno_Guilherme(matricula):
    cursor_Guilherme.execute("DELETE FROM alunos_Guilherme WHERE matricula = ?", (matricula,))
    conexao_Guilherme.commit()
    print(" Aluno excluído (se existia).")

aluno1_Guilherme = Aluno_Guilherme("Lucas Silva", "202501", "2B")
aluno2_Guilherme = Aluno_Guilherme("Mariana Costa", "202502", "2B")
aluno1_Guilherme.exibir_dados_Guilherme()
aluno2_Guilherme.exibir_dados_Guilherme()

aluno3_Guilherme = Aluno_Guilherme("Carlos Lima", "202503", "2B")
aluno3_Guilherme.set_nome_Guilherme("Carlos Eduardo Lima")
print("Nome do aluno:", aluno3_Guilherme.get_nome_Guilherme())
aluno3_Guilherme.adicionar_falta_Guilherme(3)
print(aluno3_Guilherme.verificar_situacao_Guilherme())
aluno3_Guilherme.adicionar_falta_Guilherme(2)
print(aluno3_Guilherme.verificar_situacao_Guilherme())

aluno_normal = Aluno_Guilherme("Julia Souza", "202504", "2B")
monitor = AlunoMonitor_Guilherme("Fernando Lopes", "202505", "2B", "Matemática")
aluno_normal.exibir_dados_Guilherme()
monitor.exibir_dados_Guilherme()

inserir_aluno_Guilherme("Julia Souza", "202504", "2B")
inserir_aluno_Guilherme("Fernando Lopes", "202505", "2B")
listar_alunos_Guilherme()
deletar_aluno_Guilherme("202504")
listar_alunos_Guilherme()
# Out:
# Aluno: Lucas Silva, Matrícula: 202501, Turma: 2B
# Aluno: Mariana Costa, Matrícula: 202502, Turma: 2B
# Nome do aluno: Carlos Eduardo Lima
# Carlos Eduardo Lima está com presença regular.
# Carlos Eduardo Lima está em risco por excesso de faltas!
# Aluno: Julia Souza, Matrícula: 202504, Turma: 2B
# Monitor: Fernando Lopes, Matrícula: 202505, Turma: 2B
# Disciplina que monitora: Matemática
#  Aluno inserido com sucesso!
#  Aluno inserido com sucesso!
#  Lista de alunos:
# (1, 'Julia Souza', '202504', '2B')
# (2, 'Fernando Lopes', '202505', '2B')
#  Aluno excluído (se existia).
#  Lista de alunos:
# (2, 'Fernando Lopes', '202505', '2B')

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3

# Classe principal representando um aluno
class Aluno_Guilherme:
    def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme):
        # Atributos da classe Aluno
        self.__nome_Guilherme = nome_Guilherme  # Atributo privado
        self.matricula_Guilherme = matricula_Guilherme
        self.turma_Guilherme = turma_Guilherme
        self.faltas_Guilherme = 0

    # Método GET para acessar o nome (encapsulamento)
    def get_nome_Guilherme(self):
        return self.__nome_Guilherme

    # Método SET para alterar o nome (encapsulamento)
    def set_nome_Guilherme(self, novo_nome_Guilherme):
        self.__nome_Guilherme = novo_nome_Guilherme

    # Método para verificar a situação do aluno com base nas faltas
    def verificar_situacao_Guilherme(self):
        if self.faltas_Guilherme >= 5:
            return f"{self.__nome_Guilherme} está em risco por excesso de faltas!"
        else:
            return f"{self.__nome_Guilherme} está com presença regular."

    # Método para adicionar faltas ao aluno
    def adicionar_falta_Guilherme(self, quantidade):
        self.faltas_Guilherme += quantidade

    # Método para exibir dados do aluno
    def exibir_dados_Guilherme(self):
        print(f"Aluno: {self.__nome_Guilherme}, Matrícula: {self.matricula_Guilherme}, Turma: {self.turma_Guilherme}")

# Subclasse representando um aluno monitor (herda de Aluno_Guilherme)
class AlunoMonitor_Guilherme(Aluno_Guilherme):
    def __init__(self, nome_Guilherme, matricula_Guilherme, turma_Guilherme, disciplina_monitoria_Guilherme):
        # Usando super() para chamar o construtor da classe base
        super().__init__(nome_Guilherme, matricula_Guilherme, turma_Guilherme)
        self.disciplina_monitoria_Guilherme = disciplina_monitoria_Guilherme

    # Sobrescrevendo o método exibir_dados_Guilherme para mostrar dados do monitor
    def exibir_dados_Guilherme(self):
        print(f"Monitor: {self.get_nome_Guilherme()}, Matrícula: {self.matricula_Guilherme}, Turma: {self.turma_Guilherme}")
        print(f"Disciplina que monitora: {self.disciplina_monitoria_Guilherme}")

# Conexão com o banco de dados SQLite
conexao_Guilherme = sqlite3.connect('escola_Guilherme.db')
cursor_Guilherme = conexao_Guilherme.cursor()

# Criando a tabela de alunos no banco de dados
cursor_Guilherme.execute('''
CREATE TABLE IF NOT EXISTS alunos_Guilherme (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome TEXT,
    matricula TEXT,
    turma TEXT
)
''')
conexao_Guilherme.commit()

# Função para inserir dados de um aluno no banco de dados
def inserir_aluno_Guilherme(nome, matricula, turma):
    cursor_Guilherme.execute("INSERT INTO alunos_Guilherme (nome, matricula, turma) VALUES (?, ?, ?)",
                             (nome, matricula, turma))
    conexao_Guilherme.commit()
    print(" Aluno inserido com sucesso!")

# Função para listar todos os alunos do banco de dados
def listar_alunos_Guilherme():
    cursor_Guilherme.execute("SELECT * FROM alunos_Guilherme")
    alunos = cursor_Guilherme.fetchall()
    print(" Lista de alunos:")
    for aluno in alunos:
        print(aluno)

# Função para deletar um aluno do banco de dados pelo número de matrícula
def deletar_aluno_Guilherme(matricula):
    cursor_Guilherme.execute("DELETE FROM alunos_Guilherme WHERE matricula = ?", (matricula,))
    conexao_Guilherme.commit()
    print(" Aluno excluído (se existia).")

# Testando as funcionalidades
# Criando alunos
aluno1_Guilherme = Aluno_Guilherme("Lucas Silva", "202501", "2B")
aluno2_Guilherme = Aluno_Guilherme("Mariana Costa", "202502", "2B")
aluno1_Guilherme.exibir_dados_Guilherme()
aluno2_Guilherme.exibir_dados_Guilherme()

# Testando encapsulamento e lógica
aluno3_Guilherme = Aluno_Guilherme("Carlos Lima", "202503", "2B")
aluno3_Guilherme.set_nome_Guilherme("Carlos Eduardo Lima")
print("Nome do aluno:", aluno3_Guilherme.get_nome_Guilherme())
aluno3_Guilherme.adicionar_falta_Guilherme(3)
print(aluno3_Guilherme.verificar_situacao_Guilherme())
aluno3_Guilherme.adicionar_falta_Guilherme(2)
print(aluno3_Guilherme.verificar_situacao_Guilherme())

# Testando polimorfismo
aluno_normal = Aluno_Guilherme("Julia Souza", "202504", "2B")
monitor = AlunoMonitor_Guilherme("Fernando Lopes", "202505", "2B", "Matemática")
aluno_normal.exibir_dados_Guilherme()
monitor.exibir_dados_Guilherme()

# Testando banco de dados
inserir_aluno_Guilherme("Julia Souza", "202504", "2B")
inserir_aluno_Guilherme("Fernando Lopes", "202505", "2B")
listar_alunos_Guilherme()
deletar_aluno_Guilherme("202504")
listar_alunos_Guilherme()
# Out:
# Aluno: Lucas Silva, Matrícula: 202501, Turma: 2B
# Aluno: Mariana Costa, Matrícula: 202502, Turma: 2B
# Nome do aluno: Carlos Eduardo Lima
# Carlos Eduardo Lima está com presença regular.
# Carlos Eduardo Lima está em risco por excesso de faltas!
# Aluno: Julia Souza, Matrícula: 202504, Turma: 2B
# Monitor: Fernando Lopes, Matrícula: 202505, Turma: 2B
# Disciplina que monitora: Matemática
#  Aluno inserido com sucesso!
#  Aluno inserido com sucesso!
#  Lista de alunos:
# (2, 'Fernando Lopes', '202505', '2B')
# (3, 'Julia Souza', '202504', '2B')
# (4, 'Fernando Lopes', '202505', '2B')
#  Aluno excluído (se existia).
#  Lista de alunos:
# (2, 'Fernando Lopes', '202505', '2B')
# (4, 'Fernando Lopes', '202505', '2B')
